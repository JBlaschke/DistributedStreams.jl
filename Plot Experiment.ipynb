# %%
import Pkg
Pkg.activate(@__DIR__)
# Out:
#   Activating project at `/global/u1/b/blaschke/DistributedStreams.jl`

# %%
using JLD2, FileIO, Plots

# %%
log_2 = load("worker_log_2.jld2")
log_3 = load("worker_log_3b_1.jld2")
log_4 = load("worker_log_4.jld2")
log_5 = load("worker_log_5b_1.jld2")
log_6 = load("worker_log_6b_3.jld2")
log_9 = load("worker_log_9_6.jld2")
# Out:
# Dict{String, Any} with 6 entries:
#   "n_jobs"     => 128
#   "qos"        => "regular"
#   "C"          => "gpu"
#   "N"          => 1
#   "t"          => "00:05:00"
#   "worker_log" => Dict(1713316267=>1, 1713299215=>1, 1713301635=>1, 1713300565=…

# %%
data = sort(collect(log_2["worker_log"]), by = x->x[1])
x = [d[1] for d in data]
y = [d[2] for d in data];
plot(x, y)

# %%
data = sort(collect(log_3["worker_log"]), by = x->x[1])
x = [d[1] for d in data]
y = [d[2] for d in data];
plot(x, y)

# %%
data = sort(collect(log_4["worker_log"]), by = x->x[1])
x = [d[1] for d in data]
y = [d[2] for d in data];
plot(x, y)

# %%
data = sort(collect(log_5["worker_log"]), by = x->x[1])
x = [d[1] for d in data]
y = [d[2] for d in data];
plot(x, y)

# %%
log_5["t"]
# Out:
# "00:05:00"

# %%
data = sort(collect(log_6["worker_log"]), by = x->x[1])
x = [d[1] for d in data]
y = [d[2] for d in data];
plot(x, y)

# %%
data = sort(collect(log_9["worker_log"]), by = x->x[1])
x = [d[1] for d in data]
y = [d[2] for d in data];
plot(x, y)

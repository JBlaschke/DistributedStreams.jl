# %%
import Pkg
Pkg.activate(@__DIR__)
# Out:
#   Activating project at `~/Developer/DistributedStreams.jl`

# %%
using JLD2, FileIO, Plots

# %%
log_2 = load("worker_log_2.jld2")
log_3 = load("worker_log_3b_1.jld2")
log_4 = load("worker_log_4.jld2")
log_5 = load("worker_log_5b_1.jld2")
log_6 = load("worker_log_6b_3.jld2")
log_9 = load("worker_log_9b_3.jld2")
# Out:
# Dict{String, Any} with 6 entries:
#   "n_jobs"     => 128
#   "qos"        => "regular"
#   "C"          => "cpu"
#   "N"          => 1
#   "t"          => "00:05:00"
#   "worker_log" => Dict(1713333859=>1, 1713339080=>32, 1713301635=>1, 1713332719…

# %%
data = sort(collect(log_2["worker_log"]), by = x->x[1])
x = [d[1] for d in data]./60
y = map(x->x == 1 ? 0 : x, [d[2] for d in data])
plot(
    x.-x[1], y,
    linewidth=2, box=:on, tickfont=font(10), guidefont=font(12),
    legend = false
)

# %%
data = sort(collect(log_3["worker_log"]), by = x->x[1])
x = [d[1] for d in data]./60
y = map(x->x == 1 ? 0 : x, [d[2] for d in data])
plot(
    x.-x[1], y,
    linewidth=2, box=:on, tickfont=font(10), guidefont=font(12),
    legend = false
)

# %%
data = sort(collect(log_4["worker_log"]), by = x->x[1])
x = [d[1] for d in data]./60
y = map(x->x == 1 ? 0 : x, [d[2] for d in data])
plot(
    x.-x[1], y,
    linewidth=2, box=:on, tickfont=font(10), guidefont=font(12),
    legend = false
)

# %%
data = sort(collect(log_5["worker_log"]), by = x->x[1])
x = [d[1] for d in data]./60
y = map(x->x == 1 ? 0 : x, [d[2] for d in data])
plot(
    x.-x[1], y,
    linewidth=2, box=:on, tickfont=font(10), guidefont=font(12),
    legend = false
)

# %%
log_5["t"]
# Out:
# "00:05:00"

# %%
data = sort(collect(log_6["worker_log"]), by = x->x[1])
x = [d[1] for d in data]./60
y = map(x->x == 1 ? 0 : x, [d[2] for d in data])
plot(
    x.-x[1], y,
    linewidth=2, box=:on, tickfont=font(10), guidefont=font(12),
    legend = false
)

# %%
data = sort(collect(log_9["worker_log"]), by = x->x[1])
x = [d[1] for d in data]./60
y = map(x->x == 1 ? 0 : x, [d[2] for d in data])
plot(
    x.-x[1], y,
    linewidth=2, box=:on, tickfont=font(10), guidefont=font(12),
    legend = false
)

# %%
p = plot()

data = sort(collect(log_5["worker_log"]), by = x->x[1])
x = [d[1] for d in data]./60^2
y = map(x->x == 1 ? 0 : x, [d[2] for d in data])
plot!(
    x.-x[1], y,
    linewidth=2, box=:on, tickfont=font(10), guidefont=font(12),
    label="CPU"
)

data = sort(collect(log_6["worker_log"]), by = x->x[1])
x = [d[1] for d in data]./60^2
y = map(x->x == 1 ? 0 : x, [d[2] for d in data])
plot!(
    x.-x[1], y,
    linewidth=2, box=:on, tickfont=font(10), guidefont=font(12),
    label="CPU"
)

data = sort(collect(log_9["worker_log"]), by = x->x[1])
x = [d[1] for d in data]./60^2
y = map(x->x == 1 ? 0 : x, [d[2] for d in data])
plot!(
    x.-x[1], y,
    linewidth=2, box=:on, tickfont=font(10), guidefont=font(12),
    label="GPU"
)

xlabel!("Time [h]")
ylabel!("# processors")

plot!(legend=true, dpi=600)

# savefig("backfill.png")

p
